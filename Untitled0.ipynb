# %%
# !pip install gradio openai gtts pydub numpy requests groq openai-whisper diffusers transformers torch google-generativeai soundfile datasets
# !apt-get install -y ffmpeg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 15.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 14.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 24.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 46.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 21.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.3 MB/s eta 0:00:00
# ...

# %%
import os
os.environ["GROQ_API_KEY"] = "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"

# %%
import gradio as gr
import torch
from transformers import pipeline, AutoProcessor, AutoModelForTextToSpectrogram, BlipForConditionalGeneration
from PIL import Image
from diffusers import StableDiffusionPipeline
import whisper
from gtts import gTTS
import io
import soundfile as sf
from datasets import load_dataset
import os
import requests
from groq import Groq
from transformers import SpeechT5Processor, SpeechT5ForTextToSpeech, SpeechT5HifiGan

# %%
import google.generativeai as genai

Google_api_key = "AIzaSyDjqiapSQYWaBtsRVVQkQt9tsYgrYuc_wo"
genai.configure(api_key=Google_api_key)
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
import google.generativeai as genai

# %%
from huggingface_hub import login

login(token="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")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# Initialize the models

# Text-to-Image model (Stable Diffusion)
text_to_image_pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", torch_dtype=torch.float16)
text_to_image_pipe = text_to_image_pipe.to("cuda")


# Text-to-Speech model (gTTS)
# Note: gTTS does not need model loading

# # Image-to-Text model (BLIP)
# img_processor = AutoTokenizer.from_pretrained("Salesforce/blip-image-captioning-large")
# img_caption_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-large")
# Image-to-Text model (BLIP)
img_processor = AutoProcessor.from_pretrained("Salesforce/blip-image-captioning-large")
img_caption_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-large")

# Speech-to-Speech (Whisper + Groq)
whisper_model = whisper.load_model("base")
client = Groq(api_key="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")

# Google Generative AI (Text-to-Text)
Google_api_key = "AIzaSyDjqiapSQYWaBtsRVVQkQt9tsYgrYuc_wo"
genai.configure(api_key=Google_api_key)

# Initialize the model
model = genai.GenerativeModel("gemini-1.5-flash")


# Define the functions for each functionality

# Text-to-Text Chatbot (Using Google Generative AI)
def text_to_text(user_input):
    response = model.generate_content(user_input)
    return response.text


# Text-to-Image Generation
def text_to_image(prompt):
    image = text_to_image_pipe(prompt).images[0]
    return image

# Image-to-Text Captioning
def image_to_text(image_url):
    image = Image.open(requests.get(image_url, stream=True).raw)
    inputs = img_processor(images=image, text="A picture of", return_tensors="pt")
    outputs = img_caption_model.generate(**inputs)
    caption = img_processor.decode(outputs[0], skip_special_tokens=True)
    return caption


# Load the SpeechT5 TTS pipeline
synthesizer = pipeline("text-to-speech", "microsoft/speecht5_tts")
# Load the speaker embeddings dataset
embeddings_dataset = load_dataset("Matthijs/cmu-arctic-xvectors", split="validation")


# Text-to-Speech Conversion
def text_to_speech(text, speaker_id):
    try:
        # Get the speaker embedding for the selected speaker ID
        speaker_embedding = torch.tensor(embeddings_dataset[int(speaker_id)]["xvector"]).unsqueeze(0)

        # Generate speech using the provided text and speaker embedding
        speech = synthesizer(text, forward_params={"speaker_embeddings": speaker_embedding})

        # Save the generated speech to a file
        output_path = "output_speech.wav"
        sf.write(output_path, speech["audio"], samplerate=speech["sampling_rate"])

        return output_path
    except Exception as e:
        return f"An error occurred: {e}"


# Initialize the Groq client
client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

# Load the Whisper model
model = whisper.load_model("base")  # You can choose other models like "small", "medium", "large"

# Speech-to-Speech (Voice Chat)
def speech_to_speech(file_path):
    try:
        # Load the audio file
        audio = whisper.load_audio(file_path)

        # Transcribe the audio using Whisper
        result = model.transcribe(audio)
        text = result["text"]

        # Generate a response using Groq
        chat_completion = client.chat.completions.create(
            messages=[{"role": "user", "content": text}],
            model="llama3-8b-8192",  # Replace with the correct model if necessary
        )

        # Access the response using dot notation
        response_message = chat_completion.choices[0].message.content.strip()

        # Convert the response text to speech
        tts = gTTS(response_message)
        response_audio_io = io.BytesIO()
        tts.write_to_fp(response_audio_io)  # Save the audio to the BytesIO object
        response_audio_io.seek(0)

        # Save audio to a file to ensure it's generated correctly
        with open("response.mp3", "wb") as audio_file:
            audio_file.write(response_audio_io.getvalue())

        # Return the response text and the path to the saved audio file
        return response_message, "response.mp3"

    except Exception as e:
        return f"An error occurred: {e}", None
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# (…)kpoints/scheduler_config-checkpoint.json:   0%|          | 0.00/209 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# ...

# %%
# import gradio as gr
# import google.generativeai as genai
# from transformers import pipeline

# # Configure the Google API key
# Google_api_key = "AIzaSyCuXorhJ17-qmiABnrJz5_PzbJ0F_8HBE0"
# genai.configure(api_key=Google_api_key)

# # Initialize the Google Generative AI model
# model = genai.GenerativeModel("gemini-1.5-flash")

# # Initialize other models or pipelines
# text_to_image_model = pipeline("text-to-image-generation", model="stabilityai/stable-diffusion-2")
# image_to_text_model = pipeline("image-captioning", model="Salesforce/blip-image-captioning-base")
# text_to_speech_model = pipeline("text-to-speech", model="microsoft/speecht5_tts")
# speech_to_speech_model = pipeline("automatic-speech-recognition", model="openai/whisper-base")

# # Define your functions here
# def text_to_text(user_input):
#     # Text generation using Google Generative AI
#     response = model.generate_content(user_input)
#     return response.text

# def text_to_image(prompt):
#     # Image generation using the text-to-image model
#     generated_images = text_to_image_model(prompt)
#     return generated_images[0]["image"]

# def image_to_text(img_url):
#     # Caption generation for an image using the image-to-text model
#     caption = image_to_text_model(img_url)
#     return caption[0]["caption"]

# def text_to_speech(text):
#     # Text-to-speech conversion using the text-to-speech model
#     speech_output = text_to_speech_model(text)
#     return speech_output["audio"]

# def speech_to_speech(audio):
#     # Speech-to-speech conversion using ASR and TTS models
#     transcript = speech_to_speech_model(audio)["text"]
#     response = text_to_text(transcript)
#     response_audio = text_to_speech_model(response)["audio"]
#     return response, response_audio

# Gradio Interface
with gr.Blocks() as demo:
    with gr.Tab("Text to Text"):
        text_input = gr.Textbox(label="Enter your message")
        text_output = gr.Textbox(label="Bot response")
        text_btn = gr.Button("Send")
        text_btn.click(text_to_text, inputs=text_input, outputs=text_output)

    with gr.Tab("Text to Image"):
        prompt_input = gr.Textbox(label="Describe the image")
        image_output = gr.Image(label="Generated Image")
        image_btn = gr.Button("Generate Image")
        image_btn.click(text_to_image, inputs=prompt_input, outputs=image_output)

    with gr.Tab("Image to Text"):
        img_url_input = gr.Textbox(label="Image URL")
        caption_output = gr.Textbox(label="Generated Caption")
        caption_btn = gr.Button("Generate Caption")
        caption_btn.click(image_to_text, inputs=img_url_input, outputs=caption_output)

    # with gr.Tab("Text to Speech"):
    #     tts_input = gr.Textbox(label="Enter text")
    #     tts_output = gr.Audio(label="Generated Speech")
    #     tts_btn = gr.Button("Convert to Speech")
    #     tts_btn.click(text_to_speech, inputs=tts_input, outputs=tts_output)
    with gr.Tab("Text to Speech"):
      tts_input = gr.Textbox(label="Enter text")
      speaker_id_input = gr.Number(label="Speaker ID (e.g., 7306)", value=7306)
      tts_output = gr.Audio(label="Generated Speech")
      tts_btn = gr.Button("Convert to Speech")
      tts_btn.click(text_to_speech, inputs=[tts_input, speaker_id_input], outputs=tts_output)



    # with gr.Tab("Speech to Speech"):
    #     audio_input = gr.Audio(label="Upload your speech")
    #     response_output = gr.Textbox(label="Generated Response")
    #     response_audio_output = gr.Audio(label="Response Audio")
    #     speech_btn = gr.Button("Generate Response")
    #     speech_btn.click(speech_to_speech, inputs=audio_input, outputs=[response_output, response_audio_output])

    with gr.Tab("Speech to Speech"):
        audio_input = gr.Audio(label="Upload your speech", type="filepath")  # Ensure type="filepath"
        response_output = gr.Textbox(label="Generated Response")
        response_audio_output = gr.Audio(label="Response Audio")
        speech_btn = gr.Button("Generate Response")
        speech_btn.click(speech_to_speech, inputs=audio_input, outputs=[response_output, response_audio_output])


demo.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://befbe2f3786c18d0b2.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://befbe2f3786c18d0b2.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
